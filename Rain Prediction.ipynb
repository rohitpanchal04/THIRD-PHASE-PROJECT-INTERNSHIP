# %% [markdown]
# Name  -  Rohit Kumar
#
# Batch -  DS2401

# %%
from IPython.display import Image
Image(url='https://qph.cf2.quoracdn.net/main-qimg-132f9a3e0e22748014ecba369ae1d915')
# Out:
# <img src="https://qph.cf2.quoracdn.net/main-qimg-132f9a3e0e22748014ecba369ae1d915"/>

# %% [markdown]
# # INDEX
#
# **1 - INTRODUCTION**
#
# **2 - IMPORTING NECESSARY LIBRARY**
#
# **3 - LOADING DATASET**
#
#             3.1 - FETCHING TOP 5 DATA
#             3.2 - FETCHING BOTTOM 5 DATA
#             3.3 - FETCHNG RANDOMIZED DATA
#
# **4 - DATA PROFILING**
#
#             4.1 - CHECKING SHAPE
#             4.2 - CHECKING COLUMNS
#             4.3 - CHECKING DATATYPES
#             4.4 - CHECKING INFORMATION
#             4.5 - CHECKING NULL VALUES
#             4.6 - VISUALIZING NULL VALUES
#
# # EXPLORATORY DATA ANALYSIS
#
# **5 - DATA QUALITY CHECK**
#
#             5.1 CHECKING UNIQUE VALUES OF OBJECT COLUMN
#             5.2 FILLING NULL VALUES
#             5.3 CHECKING STATISTICS
#
# **6 - DATA VISUALIZATION**
#
# **7 - FEATURE ENGINEERING**
#
#             7.1 CHECKING SKEWNESS
#                     7.1.1 REMOVING SKEWNESS BY CUBEROOT
#             7.2 CHECKING OUTLIERS
#                     7.2.1 REMOVING SKEWNESS BY ZSCORE
#             7.3 CHECKING CORRELATION
#
# **8 - MODEL BUILDING AND PREDICTION**
#
#             8.1 SEPRATING X(INDEPENDENT) & Y(TARGET)
#             8.2 STANDARD SCALING
#             8.3 VARIANCE INFLATION FACTOR
#                     8.3.1 REMOVING HIGH MULTICOLLINEAR COLUMN
#
# # PREDICTING RAIN-TOMORROW
#
# **9 - IMPORTING MACHINE LEARNING LIBRARY(CLASSIFICATION)**
#
# **10 - CHECKING BEST MODEL**
#
# **11 - HYPERTUNING**
#
# **12 - PREDICTING THE MODEL**
#
# **13 - SAVING MODEL**
#
# **14 - COMPARISON OF ORIGINAL AND PREDICTION**
#
# # PREDICTING RAINFALL
#
# **15 - SEPRATING X(INDEPENDENT) AND Y(TARGET)**
#
# **16 - STANDARD SCALING**
#
# **17 - VARIANCE INFLATION FACTOR**
#
#             17.1 - REMOVING HIGH MULTICOLLINEAR COLUMN
# **18 - IMPORTING MACHINE LEARNING LIBRARY(REGRESSION)**
#
# **19 - CHECKING BEST MODEL**
#
# **20 - HYPERTUNING**
#
# **21 - PREDICTION**
#
# **22 - SAVING MODEL**
#
# **23 - COMPARISON OF ORIGINAL AND PREDICTION**

# %% [markdown]
# # INTRODUCTION
#
# **Rainfall Weather Forecasting**
#
# **Project Description**
#
# Weather forecasting is the application of science and technology to predict the conditions of the atmosphere for a given location and time. Weather forecasts are made by collecting quantitative data about the current state of the atmosphere at a given place and using meteorology to project how the atmosphere will change.
# Rain Dataset is to predict whether or not it will rain tomorrow. The Dataset contains about 10 years of daily weather observations of different locations in Australia. Here, predict two things:
#
# 1. **Problem Statement**:
#
# a) Design a predictive model with the use of machine learning algorithms to forecast whether or not it will rain tomorrow.
#
# b) Design a predictive model with the use of machine learning algorithms to predict how much rainfall could be there.
#
#
# **Dataset Description**:
# **Number of columns: 23**
#
#
# **Date**  - The date of observation
#
# **Location**  -The common name of the location of the weather station
#
# **MinTemp**  -The minimum temperature in degrees celsius
#
# **MaxTemp** -The maximum temperature in degrees celsius
#
# **Rainfall**  -The amount of rainfall recorded for the day in mm
#
# **Evaporation**  -The so-called Class A pan evaporation (mm) in the 24 hours to 9am
#
# **Sunshine**  -The number of hours of bright sunshine in the day.
#
# **WindGustDi r**- The direction of the strongest wind gust in the 24 hours to midnight
#
# **WindGustSpeed** -The speed (km/h) of the strongest wind gust in the 24 hours to midnight
#
# **WindDir9am** -Direction of the wind at 9am
#
# **WindDir3pm** -Direction of the wind at 3pm
#
# **WindSpeed9am** -Wind speed (km/hr) averaged over 10 minutes prior to 9am
#
# **WindSpeed3pm** -Wind speed (km/hr) averaged over 10 minutes prior to 3pm
#
# **Humidity9am** -Humidity (percent) at 9am
#
# **Humidity3pm** -Humidity (percent) at 3pm
#
# **Pressure9am** -Atmospheric pressure (hpa) reduced to mean sea level at 9am
#
# **Pressure3pm** -Atmospheric pressure (hpa) reduced to mean sea level at 3pm
#
# **Cloud9am** - Fraction of sky obscured by cloud at 9am.
#
# **Cloud3pm** -Fraction of sky obscured by cloud
#
# **Temp9am** -Temperature (degrees C) at 9am
#
# **Temp3pm** -Temperature (degrees C) at 3pm
#
# **RainToday** -Boolean: 1 if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise 0
#
# **RainTomorrow** -The amount of next day rain in mm. Used to create response variable . A kind of measure of the "risk".

# %% [markdown]
# **Importing Necessary Libraries**

# %%
# Importing Necessary Library for EDA
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Loading Dataset**

# %%
# Loading data from the Link 
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Rainfall%20Forecast/Rainfall.csv')

# %%
#Fetching out top 5 data
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# Fething out bottom 5 data
df.tail()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
# ...

# %%
# fetching the Randomized data from the dataset
df.sample(5)
# Out:
#             Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5438  2010-01-20     Melbourne     14.5     28.2       0.0          6.4
# 3118  2016-08-11   Williamtown     10.0     20.0       1.4          3.4
# 2395  2014-07-14       Penrith      1.2     18.1       0.0          NaN
# 7611  2012-11-06  PerthAirport     11.4     21.8       0.8          4.8
# 2158  2015-03-11     Newcastle     21.5     29.8       0.5          NaN
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 5438      10.6         SSE           39.0         NW  ...        62.0
# 3118       NaN         WNW           39.0        WNW  ...        61.0
# 2395       NaN         ESE           20.0        NNW  ...        77.0
# 7611      10.8         WSW           41.0        WSW  ...        61.0
# 2158       NaN         NaN            NaN        NaN  ...        89.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %% [markdown]
# # DATA PROFILING

# %%
# Checking the Columns and Rows of Data
df.shape
# Out:
# (8425, 23)

# %%
# Checking Columns
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
# Checking Datatypes
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
#CHecking full Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
# Checking Null Values
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
# Lets Visualize
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %% [markdown]
# **Observation -**
#
#   1. There are 23 columns and 8425 Rows in the dataset
#   2. There are 2 datatypes in the dataset - Object & Float64
#   3. By checking the null values we get to know that there are so many Null Values
#   4. The most number of Null values in the Sunshine
#   5. The Least number of Null values in the Temp9am

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# **DATA QUALITY CHECK**

# %%
# Checking the Unique Values of Object datatype Columns 
for column in df.columns:
    if df[column].dtypes == object :
        print(str(column) + ' : ' + str(df[column].unique()))
        print(df[column].value_counts())
        print('_______________________________________________________________')
# Out:
# Date : ['2008-12-01' '2008-12-02' '2008-12-03' ... '2013-06-06' '2013-06-07'
#  '2013-06-08']
# Date
# 2011-01-31    5
# 2011-05-08    5
# 2011-05-21    5
# 2011-05-20    5
# 2011-05-19    5
#              ..
# 2013-01-28    1
# 2013-01-29    1
# 2013-01-30    1
# 2013-01-31    1
# 2013-06-08    1
# Name: count, Length: 3004, dtype: int64
# _______________________________________________________________
# Location : ['Albury' 'CoffsHarbour' 'Newcastle' 'Penrith' 'Williamtown' 'Wollongong'
#  'Melbourne' 'Brisbane' 'Adelaide' 'PerthAirport' 'Darwin' 'Uluru']
# Location
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: count, dtype: int64
# _______________________________________________________________
# ...

# %% [markdown]
# **Observation -**
#
#     1. Location - The dataset is of Australian state in which most of the Prediction comes from Melbourne and least one is from Uluru
#     2. Rain Today & Rain Tomorrow - In the most of the cases it is happening that I f Rain today Happen then Rain Tommorow will definetly happen & Vice Versa.

# %%
# Seprating Date column into Year, MOnth, & Day 
df['Date']= pd.to_datetime(df["Date"])
#Creating a column of year
df['year'] = df.Date.dt.year
df['month'] = df.Date.dt.month
df['day'] = df.Date.dt.day

# %%
# Dropping Date Column 
df.drop(columns='Date',inplace=True)

# %% [markdown]
# **Data Filling**

# %% [markdown]
# **Get list of categorical variables**

# %%
cat = (df.dtypes == "object")
object_cols = list(cat[cat].index)

print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %% [markdown]
# **Missing values in categorical variables**

# %%
for i in object_cols:
    print(i, df[i].isnull().sum())
# Out:
# Location 0
# WindGustDir 991
# WindDir9am 829
# WindDir3pm 308
# RainToday 240
# RainTomorrow 239

# %% [markdown]
# **Filling missing values with mode of the column in value**

# %%
for i in object_cols:
    df[i].fillna(df[i].mode()[0], inplace=True)

# %% [markdown]
# **Get list of Numerical Columns**

# %%
num=(df.dtypes=='float64')
num_cols=list(num[num].index)

print("Numerical Columns")
print(num_cols)
# Out:
# Numerical Columns
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %% [markdown]
# **Missing Values in the Numerical Columns**

# %%
for i in num_cols:
    print(i, df[i].isnull().sum())
# Out:
# MinTemp 75
# MaxTemp 60
# Rainfall 240
# Evaporation 3512
# Sunshine 3994
# WindGustSpeed 991
# WindSpeed9am 76
# WindSpeed3pm 107
# Humidity9am 59
# Humidity3pm 102
# Pressure9am 1309
# Pressure3pm 1312
# Cloud9am 2421
# Cloud3pm 2455
# Temp9am 56
# Temp3pm 96

# %% [markdown]
# **Filling missing values with mean of the column in value**

# %%
for i in num_cols:
    df[i].fillna(df[i].mode()[0], inplace=True)

# %%
# Visualizing the Null Values
sns.heatmap(df.isnull(),cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# year             0
# month            0
# day              0
# dtype: int64

# %% [markdown]
# # Checking Statistics

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean     13.182682    23.825365     2.725982     4.810220     4.014042
# std       5.380656     6.128159    10.319872     3.912448     4.744297
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.300000    19.200000     0.000000     4.000000     0.000000
# 50%      13.200000    23.200000     0.000000     4.000000     0.200000
# 75%      17.300000    28.000000     0.800000     5.200000     8.900000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    8425.000000   8425.000000   8425.000000  8425.000000  8425.000000
# mean       40.036320     13.803917     18.412582    67.858754    51.295193
# std        13.781296     10.138945      9.763307    16.779787    18.316487
# ...

# %% [markdown]
# **Summary Statistics**
#
# - **Count:** 8425 rows
# - **Columns:** 21 columns
#
# **Temperature**
#
# - **Min Temp:** -2°C
# - **Max Temp:** 45.5°C
# - **Mean Temp (9am):** 13.182682°C
# - **Mean Temp (3pm):** 23.825365°C
#
# **Precipitation**
#
# - **Min Rainfall:** 0 mm
# - **Max Rainfall:** 371 mm
#
# **Wind**
#
# - **Mean Wind Gust Speed:** 40.036320 km/h
# - **Mean Wind Speed 9am:** 13.803917 km/h
# - **Mean Wind Speed 3pm:** 18.412582 km/h
#
# **Humidity**
#
# - **Mean Humidity 9am:** 67.858754%
# - **Mean Humidity 3pm:** 51.295193%
#
# **Pressure**
#
# - **Mean Pressure 9am:** 1017.198944 hPa
# - **Mean Pressure 3pm:** 1015.635347 hPa
#
# **Cloud Cover**
#
# - **Mean Cloud Cover 9am:** 5.265875 oktas
# - **Mean Cloud Cover 3pm:** 5.230742 oktas
#
# These statistics provide a comprehensive overview of the weather data recorded, encompassing temperature variations, precipitation levels, wind characteristics, humidity levels, atmospheric pressure, and cloud cover throughout the dataset.onth: 6.442136
# Mean Day: 15.741958

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,6))
plt.xlabel('RainTommorow')
sns.countplot(data=df,x='RainTomorrow')
plt.show()

# %% [markdown]
# **Observation -**
#
#     1. More number of No
#     2. Less number of Yes

# %%
N = 5  # Number of top locations to display
top_locations = df.nlargest(N, 'MinTemp')

# Create a pie chart
plt.figure(figsize=(10, 7))
plt.pie(top_locations['MinTemp'], labels=top_locations['Location'], autopct='%1.1f%%')
plt.title(f"Top {N} Locations with Minimum Temperature")
plt.show()

# %%
N = 5  # Number of top locations to display
top_locations = df.nlargest(N, 'MaxTemp')

# Create a pie chart
plt.figure(figsize=(10, 7))
plt.pie(top_locations['MaxTemp'], labels=top_locations['Location'], autopct='%1.1f%%')
plt.title(f"Top {N} Locations with Maximum Temperature")
plt.show()

# %%
plt.plot(df.index, df['Temp9am'], label='9am Temperature')
plt.plot(df.index, df['Temp3pm'], label='3pm Temperature')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperatures at 9am and 3pm')
plt.legend()
plt.show()

# %% [markdown]
# **Observation-**
#
#     1. Tempreature at 3PM is more
#     2. Tempreature at 9AM is less

# %%
fig, ax = plt.subplots(figsize=(10, 6))
for location, data in df.groupby('Location'):
    ax.hist(data['Rainfall'], bins=20, alpha=0.5, label=location)
ax.set_xlabel('Rainfall (mm)')
ax.set_ylabel('Frequency')
ax.set_title('Rainfall Distribution by Location')
ax.legend()
plt.show()

# %% [markdown]
# **Observation-**
#
#       1. Most RainFall in the 'Metlbourne' &
#       2. Least Number of Rainfall recorded in the 'Wollongong'

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['RainToday'], df['RainTomorrow'], alpha=0.5)
plt.xlabel('Rain today (0 = no, 1 = yes)')
plt.ylabel('Rain tomorrow (0 = no, 1 = yes)')
plt.title('Relationship between Rain today and Rain tomorrow')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Humidity9am', y='RainToday', data=df, alpha=0.5)
plt.xlabel('Humidity 9am')
plt.ylabel('Rain ')
plt.title('Relationship between Humidity and Rain')
plt.show()

# %% [markdown]
# **Observation-**
#
#       1. When the Humidity is more the chance of Rain is Increase

# %%
plt.plot(df.index, df['Humidity9am'], label='9AM Humidity')
plt.plot(df.index, df['Humidity3pm'], label='3PM Humidity')
plt.xlabel('Time')
plt.ylabel('Humidity')
plt.title('Humidity at 9am and 3pm')
plt.legend()
plt.show()

# %% [markdown]
# **Observation-**
#
#     1. At 3PM Humidity is more than 9AM

# %%
plt.figure(figsize=(12, 8))
plt.bar(df['month'], df['Rainfall'],color='orange')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.title('Monthly Rainfall Distribution')
 
plt.xticks( range(1,13),['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %% [markdown]
# **Observation-**
#
#     1. In November the most Rainfall recorded & In August least Rainfall recorded

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['year'], df['Rainfall'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.title('Yearly Rainfall Distribution')
             
plt.xticks([2008,2009,2010,2011,2012,2013,2014,2015,2016,2017])
plt.show()

# %% [markdown]
# **Observation-**
#
#     1. In Year 2009 most Rainfall recorded & In year 2008,2014,2017 least Rainfall recorded

# %%
plt.figure(figsize=(10, 6))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', 
          '#8dd3c7', '#bebada', '#fc8d62', '#bf5b17', '#cffccc', 
          '#7f7f7f', '#c7c7c7']
locations = df['Location'].unique()

for i, location in enumerate(locations):
    location_data = df[df['Location'] == location]
    plt.bar(location_data['year'], location_data['Rainfall'], color=colors[i], label=location)

plt.xlabel('Year')
plt.ylabel('Rainfall in mm')
plt.title('Yearly Rainfall Distribution')
plt.xticks([2008,2009,2010,2011,2012,2013,2014,2015,2016,2017])
plt.legend()
plt.show()

# %% [markdown]
# **Observation-**
#
#     1. In 2008 most Rainfall in 'Wollongong'
#     2. In 2009 most Rainfall in 'Coffshrbour'
#     3. In 2010 most Rainfall in 'Coffshrbour'
#     4. In 2011 most Rainfall in ' Perth Airport'
#     5. In 2012 most Rainfall in 'Darwin'
#     6. In 2013 most Rainfall in 'Newcastle'
#     7. In 2014 most Rainfall in 'PerthAirport'
#     8. In 2015 most Rainfall in 'Newcastle'
#     9. In 2016-2017 most Rainfall in 'Albury'

# %% [markdown]
# # FEATURE ENGINEERING

# %%
# VISUALIZING THE DISTRIBUTION OF THE NUMERICAL DATASET
df.hist(figsize=(20,12))
plt.show()

# %% [markdown]
# # CHEKING SKEWNESS

# %%
# CHECKING THE SKEWNESS
df[num_cols].skew()
# Out:
# MinTemp          -0.084104
# MaxTemp           0.391512
# Rainfall         13.200523
# Evaporation      13.812740
# Sunshine          0.606448
# WindGustSpeed     0.786153
# WindSpeed9am      0.969604
# WindSpeed3pm      0.510765
# Humidity9am      -0.262767
# Humidity3pm       0.110858
# Pressure9am       0.171566
# Pressure3pm      -0.190150
# Cloud9am         -0.863322
# Cloud3pm         -0.804407
# Temp9am          -0.005160
# Temp3pm           0.412119
# dtype: float64

# %% [markdown]
# **OBSERVATION-**
#
#     1. In Rainfall & Evaporation the Skewness is to high

# %%
# Removing the Skewness using Cuberoot method
df['Rainfall']=np.cbrt(df['Rainfall'])
df['Evaporation']=np.cbrt(df['Evaporation'])

print('New skewness Rainfall -',df['Rainfall'].skew())
print('\n')
print('New Skewneww Evaporation - ',df['Evaporation'].skew())
# Out:
# New skewness Rainfall - 1.7625607533187797
#
#
# New Skewneww Evaporation -  0.8257587640198553

# %%
df.hist(figsize=(20,12))
plt.show()

# %% [markdown]
# **Observation-**
#
#     Now the distribution of the Numerical Column is looking Bell curve and Log normal Distribution - 'Windspeed9AM'

# %% [markdown]
# # Checking Outliers

# %%
# Checking the Outliler by Box Plot
df.plot(kind='box',figsize=(15,8),subplots=True,layout=(3,7))
plt.show()

# %% [markdown]
# **Removing Outlier by 'Zscore' method**

# %%
from scipy.stats import zscore
z=np.abs(zscore(df[num_cols]))
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (7943, 25)

# %%
print('Data Deduction - ',df.shape[0]-df_new.shape[0])
# Out:
# Data Deduction -  482

# %%
# Dropping the Day Column 
df_new.drop(columns='day',inplace =True)

# %% [markdown]
# **Using 'Label Encoder' Categorical to Numerical**

# %%
# Importing LabelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
#Categorical column
list1=['Location',
 'WindGustDir',
 'WindDir9am',
 'WindDir3pm',
 'RainToday',
 'RainTomorrow']
for val in list1:
    df_new[val]=le.fit_transform(df_new[val].astype(str))

# %% [markdown]
# **Shifting Year Column from Last to One**

# %%
# Define the column to shift
column_to_shift = 'year'

# Define the new position for the column
new_position = 0

# Get the current columns
columns = list(df_new.columns)

# Remove the column from its current position
columns.remove(column_to_shift)

# column at the new position
columns.insert(new_position, column_to_shift)
df_new = df_new[columns]
df_new.head(1)
# Out:
#    year  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008         1     13.4     22.9  0.843433     1.587401       0.0
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# 0           13           44.0          13  ...         22.0       1007.7
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0       1007.1       8.0       7.0     16.9     21.8          0             0
#
#    month
# 0     12
#
# [1 rows x 24 columns]

# %% [markdown]
# **Shifting Month column Last to Second**

# %%
# Define the column to shift
column_to_shift = 'month'

# Define the new position for the column
new_position = 1

# Get the current columns
columns = list(df_new.columns)

# Remove the column from its current position
columns.remove(column_to_shift)

# Column at the new position
columns.insert(new_position, column_to_shift)
df_new = df_new[columns]
df_new.head(1)
# Out:
#    year  month  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008     12         1     13.4     22.9  0.843433     1.587401       0.0
#
#    WindGustDir  WindGustSpeed  ...  Humidity9am  Humidity3pm  Pressure9am  \
# 0           13           44.0  ...         71.0         22.0       1007.7
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 0       1007.1       8.0       7.0     16.9     21.8          0             0
#
# [1 rows x 24 columns]

# %% [markdown]
# # Checking Correlation

# %%
# Checking Correlation
df_new.corr()
# Out:
#                    year     month  Location   MinTemp   MaxTemp  Rainfall  \
# year           1.000000 -0.092846  0.480379  0.037744  0.114474  0.009220
# month         -0.092846  1.000000 -0.086484 -0.247041 -0.162384 -0.007180
# Location       0.480379 -0.086484  1.000000  0.117311  0.063164  0.014296
# MinTemp        0.037744 -0.247041  0.117311  1.000000  0.717558  0.074891
# MaxTemp        0.114474 -0.162384  0.063164  0.717558  1.000000 -0.225839
# Rainfall       0.009220 -0.007180  0.014296  0.074891 -0.225839  1.000000
# Evaporation    0.073330 -0.026105  0.094834  0.401047  0.488212 -0.177774
# Sunshine      -0.273105  0.026512 -0.098944  0.148425  0.298483 -0.159859
# WindGustDir   -0.095259  0.038160 -0.037557 -0.153579 -0.230732  0.122409
# WindGustSpeed -0.044292  0.044085  0.244552  0.232564  0.135434  0.082333
# WindDir9am    -0.034059  0.018476 -0.040116 -0.042436 -0.212802  0.152821
# WindDir3pm    -0.008567  0.028973 -0.030647 -0.154445 -0.189246  0.111546
# ...

# %%
# VIsualiing the Correlation by Heatmap
plt.figure(figsize=(25,15))
sns.heatmap(df_new.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# **Observartion-**
#
# The correlation matrix shows the relationship between different variables in a dataset.
#
# Here are some key observations from the matrix:
#
# **Strong positive correlation**: The highest positive correlation is between "RainToday" and "RainTomorrow" (correlation coefficient around 0.5). This indicates a strong association - when it rains today, it's likely to rain tomorrow.
#
# **Moderate positive correlation**: The variables "MinTemp" and "MaxTemp" show moderate positive correlation.
# This makes sense, as generally higher minimum temperatures lead to higher maximum temperatures.
#
# **Weak correlations**: Many variables have weak correlations, both positive and negative.This indicates there's not a strong linear relationship between them.
#
# **Negative correlations**: Some variables have negative correlations. For example, there is a negative correlation between "RainToday" and "Sunshine."
# This suggests that rainy days are associated with lower levels of sunshine.

# %% [markdown]
# # Model Building and Predicting

# %% [markdown]
# **Seprating Independent (X) & Target (Y) Variable**

# %%
x=df_new.iloc[:,:-1]
y=df_new['RainTomorrow']

# %%
x.head(2)

# %% [markdown]
# **Standard Scaler - for scaling the full data into One Frame**

# %%
# Importing StandardScaler 
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()

# %%
# Scaling the X(Independent Variable)
x_scaled=pd.DataFrame(st.fit_transform(x),columns=x.columns)
x_scaled.head()

# %% [markdown]
# **Variance Inflation Factor - for checking the Multicollinearity of the column to Target Variable**

# %%
# Importing Variance Inflation Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x_scaled.values,i) for i in range (len(x_scaled.columns))]
vif['features']=x_scaled.columns
vif

# %% [markdown]
# **'Temp3pm' has the highest number of VIF which means it is multicollinear**

# %%
# Removing the 'Temp3pm' column 
x_scaled.drop(columns='Temp3pm',inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x_scaled.values,i) for i in range (len(x_scaled.columns))]
vif['features']=x_scaled.columns
vif

# %% [markdown]
# **'Temp9am' Column has the highest Multicollinearity so we are now removing it for making our data more relaible**

# %%
# Dropping the Temp9am column
x_scaled.drop(columns='Temp9am',inplace=True)

# %%
# Checking VIF again
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x_scaled.values,i) for i in range (len(x_scaled.columns))]
vif['features']=x_scaled.columns
vif

# %% [markdown]
# **Now our Data is more clear we can move to the next part of modelling**

# %% [markdown]
# # Predicting Rain Tomorrow by Classification model

# %%
# Importing Machine Learning Library - Classification
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.tree import DecisionTreeClassifier 
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import GaussianNB 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.tree import ExtraTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,recall_score
from sklearn.model_selection import train_test_split

# %%
# Checking which Classification model is best among all of them
KNN=KNeighborsClassifier()
DTC=DecisionTreeClassifier()
LR=LogisticRegression()
RFC=RandomForestClassifier()
GNB=GaussianNB()
ETC=ExtraTreeClassifier()
SVC=SVC()

model = [KNN,DTC,LR,RFC,GNB,ETC,SVC]
max_accuracy_score=0
for r_state in range(45,85):
    x_train, x_test, y_train,y_test=train_test_split(x_scaled,y,random_state=r_state, test_size=0.25)
    for i in model:
        i.fit(x_train, y_train)
        pre = i.predict(x_test)
        acc=accuracy_score(y_test,pre)
        print('Accuracy Score correspond to random state',r_state,'is',acc)
        if acc>max_accuracy_score:
            max_accuracy_score=acc
            final_state=r_state
            final_model=i
print()
print('Accuracy Score to random state',final_state,'is',max_accuracy_score, 'and model is',final_model)
# Out:
# Accuracy Score correspond to random state 50 is 0.8393756294058409
# Accuracy Score correspond to random state 50 is 0.8348439073514602
# Accuracy Score correspond to random state 50 is 0.8373615307150051
# Accuracy Score correspond to random state 50 is 0.8942598187311178
# Accuracy Score correspond to random state 50 is 0.7744209466263847
# Accuracy Score correspond to random state 50 is 0.8343403826787512
# Accuracy Score correspond to random state 50 is 0.8569989929506546
# Accuracy Score correspond to random state 51 is 0.8353474320241692
# Accuracy Score correspond to random state 51 is 0.8529707955689829
# Accuracy Score correspond to random state 51 is 0.823766364551863
# Accuracy Score correspond to random state 51 is 0.8841893252769386
# Accuracy Score correspond to random state 51 is 0.7849949647532729
# Accuracy Score correspond to random state 51 is 0.8343403826787512
# Accuracy Score correspond to random state 51 is 0.8418932527693856
# ...

# %% [markdown]
# **Among all of the Classification Model 'Random Forest Classifier' works very best in that prediction with the best Accuracy Rate of 90 %**

# %% [markdown]
# # Hupertuning the Model

# %%
# Importing the GridSearchCV for Hypertuning the MOdel
from sklearn.model_selection import GridSearchCV

# %%
#checking the best parameters for prediction of RandomForestClassifier algo using GridsearchCV
x_train, x_test,y_train,y_test=train_test_split(x,y,random_state=final_state,test_size=0.25)
RFC=RandomForestClassifier()
parameters={'n_estimators':range(1,45)}
gridsearch=GridSearchCV(RFC,parameters)
gridsearch.fit(x_train,y_train)
gv=gridsearch.best_params_
gv
# Out:
# {'n_estimators': 43}

# %%
model_grid = RandomForestClassifier(n_estimators=29) 
model=model_grid.fit(x_train, y_train) 
y_pred_grid = model.predict(x_test) 
gridacc=accuracy_score(y_pred_grid,y_test)
print("ACCURACY SCORE -->",accuracy_score(y_pred_grid,y_test))
# Out:
# ACCURACY SCORE --> 0.9078549848942599

# %% [markdown]
# # Saving the Model

# %%
# Importing Joblib for saving the predicted model
import joblib

# %%
joblib.dump(model_grid,'RainTomorrow.pkl')
# Out:
# ['RainTomorrow.pkl']

# %%
model=joblib.load("RainTomorrow.pkl")
prediction=model.predict(x_test)
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # Comparison of Original and Predicted

# %%
a=np.array(y_test)
df=pd.DataFrame()
df["Predicted"]=y_pred_grid
df["Original"]=a
df
# Out:
#       Predicted  Original
# 0             0         0
# 1             0         0
# 2             0         1
# 3             0         0
# 4             0         0
# ...         ...       ...
# 1981          0         0
# 1982          0         0
# 1983          0         0
# 1984          0         1
# 1985          0         0
#
# [1986 rows x 2 columns]

# %% [markdown]
# # PREDICTING RAIN FALL

# %% [markdown]
# **Shifting The Rainfall to the Last**

# %%
# Define the column to shift
column_to_shift = 'Rainfall'

# Define the new position for the column
new_position = 23

# Get the current columns
columns = list(df_new.columns)

# Remove the column from its current position
columns.remove(column_to_shift)

# column at the new position
columns.insert(new_position, column_to_shift)
df_new = df_new[columns]
df_new.head(1)
# Out:
#    year  month  Location  MinTemp  MaxTemp  Evaporation  Sunshine  \
# 0  2008     12         1     13.4     22.9     1.587401       0.0
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# 0           13           44.0          13  ...         22.0       1007.7
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0       1007.1       8.0       7.0     16.9     21.8          0             0
#
#    Rainfall
# 0  0.843433
#
# [1 rows x 24 columns]

# %% [markdown]
# **Seprating Data into X(Independent) & Y (Target) Variable**

# %%
# Seprating Data into X and Y
x=df_new.iloc[:,:-1]
y=df_new['Rainfall']

# %%
x.head(1)
# Out:
#    year  month  Location  MinTemp  MaxTemp  Evaporation  Sunshine  \
# 0  2008     12         1     13.4     22.9     1.587401       0.0
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 0           13           44.0          13  ...         71.0         22.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       7.0     16.9     21.8          0
#
#    RainTomorrow
# 0             0
#
# [1 rows x 23 columns]

# %%
y.head(2)
# Out:
# 0    0.843433
# 1    0.000000
# Name: Rainfall, dtype: float64

# %% [markdown]
# **Standard Scaling**

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()

# %%
x_scaled=pd.DataFrame(st.fit_transform(x),columns=x.columns)
x_scaled.head()
# Out:
#        year     month  Location   MinTemp   MaxTemp  Evaporation  Sunshine  \
# 0 -1.661018  1.631432 -1.505605  0.055464 -0.144969    -0.105126 -0.848544
# 1 -1.661018  1.631432 -1.505605 -1.057743  0.220995    -0.105126 -0.848544
# 2 -1.661018  1.631432 -1.505605 -0.037303  0.320803    -0.105126 -0.848544
# 3 -1.661018  1.631432 -1.505605 -0.723781  0.703402    -0.105126 -0.848544
# 4 -1.661018  1.631432 -1.505605  0.816156  1.418696    -0.105126 -0.848544
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 0     1.230078       0.375305    1.252492  ...     0.185632    -1.622479
# 1     1.442601       0.375305   -0.276038  ...    -1.452270    -1.456094
# 2     1.655124       0.532020    1.252492  ...    -1.816249    -1.178784
# 3    -0.682625      -1.191852    0.379047  ...    -1.391607    -1.955251
# 4     1.230078       0.140231   -1.367845  ...     0.852926    -1.012398
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm  \
# ...

# %% [markdown]
# # Checking Multicollinearity by Variance Inflation Factor(VIF)

# %%
# Importing Variance Inflation Factor 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x_scaled.values,i) for i in range (len(x_scaled.columns))]
vif['features']=x_scaled.columns
vif
# Out:
#     VIF Values       features
# 0     1.693752           year
# 1     1.153066          month
# 2     1.575303       Location
# 3     8.738223        MinTemp
# 4    24.697373        MaxTemp
# 5     1.499525    Evaporation
# 6     2.277630       Sunshine
# 7     1.648542    WindGustDir
# 8     2.470365  WindGustSpeed
# 9     1.333410     WindDir9am
# 10    1.491624     WindDir3pm
# 11    2.184507   WindSpeed9am
# 12    2.006842   WindSpeed3pm
# 13    3.908898    Humidity9am
# 14    5.630336    Humidity3pm
# 15    8.364540    Pressure9am
# 16    8.311117    Pressure3pm
# 17    2.161054       Cloud9am
# 18    1.903308       Cloud3pm
# 19   17.712464        Temp9am
# 20   31.965181        Temp3pm
# 21    1.356980      RainToday
# 22    1.420467   RainTomorrow

# %%
# Removing 'Temp3pm' column which has highest multicollinearity among all the colunm
x_scaled.drop(columns='Temp3pm',inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x_scaled.values,i) for i in range (len(x_scaled.columns))]
vif['features']=x_scaled.columns
vif
# Out:
#     VIF Values       features
# 0     1.693521           year
# 1     1.139480          month
# 2     1.574549       Location
# 3     8.694770        MinTemp
# 4     9.023422        MaxTemp
# 5     1.499089    Evaporation
# 6     2.253310       Sunshine
# 7     1.642395    WindGustDir
# 8     2.460200  WindGustSpeed
# 9     1.331588     WindDir9am
# 10    1.489355     WindDir3pm
# 11    2.184478   WindSpeed9am
# 12    1.999669   WindSpeed3pm
# 13    3.462657    Humidity9am
# 14    3.787814    Humidity3pm
# 15    8.167088    Pressure9am
# 16    8.150854    Pressure3pm
# 17    2.160921       Cloud9am
# 18    1.886461       Cloud3pm
# 19   16.281072        Temp9am
# 20    1.355711      RainToday
# 21    1.420462   RainTomorrow

# %%
# Removing 'Temp9am' column which has highest multicollinearity among all the colunm
x_scaled.drop(columns='Temp9am',inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x_scaled.values,i) for i in range (len(x_scaled.columns))]
vif['features']=x_scaled.columns
vif
# Out:
#     VIF Values       features
# 0     1.657413           year
# 1     1.126840          month
# 2     1.572541       Location
# 3     4.493153        MinTemp
# 4     5.481249        MaxTemp
# 5     1.498465    Evaporation
# 6     2.252635       Sunshine
# 7     1.639752    WindGustDir
# 8     2.428077  WindGustSpeed
# 9     1.331537     WindDir9am
# 10    1.488821     WindDir3pm
# 11    2.145453   WindSpeed9am
# 12    1.951913   WindSpeed3pm
# 13    2.443978    Humidity9am
# 14    3.088796    Humidity3pm
# 15    8.163167    Pressure9am
# 16    8.132234    Pressure3pm
# 17    2.122134       Cloud9am
# 18    1.877262       Cloud3pm
# 19    1.352909      RainToday
# 20    1.420075   RainTomorrow

# %% [markdown]
# **Now the Data Looks good we can go to the Next Part**

# %% [markdown]
# **Importing Machine Learning Library - Regression**

# %%
# Importing Machine Learning Library (Regression)
from sklearn.neighbors import KNeighborsRegressor  
from sklearn.tree import DecisionTreeRegressor 
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.metrics import f1_score

# %%
# CHecking the Regression model which works better there
KNR=KNeighborsRegressor()
DTR=DecisionTreeRegressor()
LR=LinearRegression()
RFR=RandomForestRegressor()
ls=Lasso()
rd=Ridge()

model = [KNR,DTR,LR,RFR,ls,rd]
max_r2_score=0
for r_state in range(45,85):
    x_train, x_test, y_train,y_test=train_test_split(x,y,random_state=r_state, test_size=0.25)
    for i in model:
        i.fit(x_train, y_train)
        pre = i.predict(x_test)
        r2_sc=r2_score(y_test,pre)
        print('R2 Score correspond to random state',r_state,'is',r2_sc)
        if r2_sc>max_r2_score:
            max_r2_score=r2_sc
            final_state2=r_state
            final_model=i
print()
print('max r2 score correspond to random state',final_state2,'is',max_r2_score, 'and model is',final_model)
# Out:
# R2 Score correspond to random state 45 is 0.31680307904244975
# R2 Score correspond to random state 45 is 0.7683038093098155
# R2 Score correspond to random state 45 is 0.8263867799948834
# R2 Score correspond to random state 45 is 0.8706851144672831
# R2 Score correspond to random state 45 is 0.19457225495103614
# R2 Score correspond to random state 45 is 0.8263935960062982
# R2 Score correspond to random state 46 is 0.31714809255209986
# R2 Score correspond to random state 46 is 0.762946981092621
# R2 Score correspond to random state 46 is 0.8334390537577138
# R2 Score correspond to random state 46 is 0.8756518790197125
# R2 Score correspond to random state 46 is 0.2038806423506494
# R2 Score correspond to random state 46 is 0.8334556489515258
# R2 Score correspond to random state 47 is 0.2652732068467277
# R2 Score correspond to random state 47 is 0.7693342168029458
# R2 Score correspond to random state 47 is 0.824862800780138
# ...

# %% [markdown]
# **Random Forest Regression is the best model here with the R2 Score of 88.77%**

# %% [markdown]
# # HyperTuning the model

# %%
# Checking the which Parameter is the best here so we can get more accurate prediction
x_train, x_test,y_train,y_test=train_test_split(x,y,random_state=final_state2,test_size=0.25)
RM=RandomForestRegressor()
parameters={'n_estimators':range(1,45)}
# Hypertuning the model by GridSearchCV
gridsearch=GridSearchCV(RM,parameters)
gridsearch.fit(x_train,y_train)
gv=gridsearch.best_params_
gv
# Out:
# {'n_estimators': 44}

# %%
# Predicting the model with the best parameter 
RFR=RandomForestRegressor(n_estimators=39)
RFR.fit(x_train,y_train)
pred=RFR.predict(x_test)
r2_sc=r2_score(y_test,pred)
adjusted_r_squared = 1 - (1-r2_sc)*(len(y)-1)/(len(y)-x.shape[1]-1)
print('R2 Score:',r2_sc)
print('Adj R2 Score:',adjusted_r_squared)
# Out:
# R2 Score: 0.8877415316344623
# Adj R2 Score: 0.8874154873394242

# %% [markdown]
# **Saving the Model**

# %%
import joblib

# %%
joblib.dump(RFR,'RainFall_Prediction.pkl')
# Out:
# ['RainFall_Prediction.pkl']

# %%
model=joblib.load('RainFall_Prediction.pkl')
predction=model.predict(x_test)
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # Comparing the model between Original and Prediction

# %%
a=np.array(y_test)
df=pd.DataFrame()
df["Predicted"]=pred
df["Original"]=a
df
# Out:
#       Predicted  Original
# 0      0.052780  0.000000
# 1      0.255246  0.736806
# 2      1.566492  1.118689
# 3      0.432565  0.584804
# 4      1.434638  1.765174
# ...         ...       ...
# 1981   1.548431  1.118689
# 1982   0.138284  0.000000
# 1983   0.021626  0.000000
# 1984   1.575811  1.912931
# 1985   0.036621  0.000000
#
# [1986 rows x 2 columns]

# %% [markdown]
# **THANKYOU**
